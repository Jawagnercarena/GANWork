# %%
from scipy import misc
f=misc.face()
misc.imsave('face.png', face)

import matplotlib.pyplot as plt
plt.imshow(f)
plt.show()

# %%
face = misc.face()
misc.imsave('face.png', face) #Creates PNG file

face = misc.imread('face.png')
type(face)
face.shape, face.dtype
# Out:
# ((768, 1024, 3), dtype('uint8'))

# %%
face = misc.face(gray=True)
face[0, 40]
# Out:
# 127

# %%
#Slicing
face[10:13, 20:23]
# Out:
# array([[141, 153, 145],
#        [133, 134, 125],
#        [ 96,  92,  94]], dtype=uint8)

# %%
lx, ly =face.shape

# %%
crop_face = face[:,ly/4:-ly/4]
print crop_face
# Out:
# [[140 146 158 ...,  66  68  70]
#  [ 84 110 148 ...,  68  69  70]
#  [ 46  74 110 ...,  71  70  69]
#  ...,
#  [ 20  21  22 ...,  14  14  14]
#  [ 21  21  21 ...,  18  18  19]
#  [ 21  21  21 ...,  23  23  23]]

# %%
plt.imshow(crop_face)
plt.show()
